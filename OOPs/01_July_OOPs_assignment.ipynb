# %% [markdown]
# 1. What is the primary goal of Object-Oriented Programming (OOP)?
# 2. What is an object in Python?
# 3. What is a class in Python?
# 4. What are attributes and methods in a class?
# 5. What is the difference between class variables and instance variables in Python?
# 6. What is the purpose of the self parameter in Python class methods?
# 7. For a library management system, you have to design the "Book" class with OOP
# principles in mind. The “Book” class will have following attributes:
# a. title: Represents the title of the book.
# b. author: Represents the author(s) of the book.
# c. isbn: Represents the ISBN (International Standard Book Number) of the book.
# d. publication_year: Represents the year of publication of the book.
# e. available_copies: Represents the number of copies available for checkout.
# The class will also include the following methods:
# a. check_out(self): Decrements the available copies by one if there are copies
# available for checkout.
# b. return_book(self): Increments the available copies by one when a book is
# returned.
# c. display_book_info(self): Displays the information about the book, including its
# attributes and the number of available copies.
#
# 8. For a ticket booking system, you have to design the "Ticket" class with OOP
# principles in mind. The “Ticket” class should have the following attributes:
# a. ticket_id: Represents the unique identifier for the ticket.
# b. event_name: Represents the name of the event.
# c. event_date: Represents the date of the event.
# d. venue: Represents the venue of the event.
# e. seat_number: Represents the seat number associated with the ticket.
# f. price: Represents the price of the ticket.
# g. is_reserved: Represents the reservation status of the ticket.
# The class also includes the following methods:
# a. reserve_ticket(self): Marks the ticket as reserved if it is not already reserved.
# b. cancel_reservation(self): Cancels the reservation of the ticket if it is already
# reserved.
# c. display_ticket_info(self): Displays the information about the ticket, including its
# attributes and reservation status.
#
# 9. You are creating a shopping cart for an e-commerce website. Using OOP to model
# the "ShoppingCart" functionality the class should contain following attributes and
# methods:
# a. items: Represents the list of items in the shopping cart.
# The class also includes the following methods:
#
# a. add_item(self, item): Adds an item to the shopping cart by appending it to the
# list of items.
# b. remove_item(self, item): Removes an item from the shopping cart if it exists in
# the list.
# c. view_cart(self): Displays the items currently present in the shopping cart.
# d. clear_cart(self): Clears all items from the shopping cart by reassigning an
# empty list to the items attribute.
#
# 10. Imagine a school management system. You have to design the "Student" class using
# OOP concepts.The “Student” class has the following attributes:
# a. name: Represents the name of the student.
# b. age: Represents the age of the student.
# c. grade: Represents the grade or class of the student.
# d. student_id: Represents the unique identifier for the student.
# e. attendance: Represents the attendance record of the student.
# The class should also include the following methods:
# a. update_attendance(self, date, status): Updates the attendance record of the
# student for a given date with the provided status (e.g., present or absent).
# b. get_attendance(self): Returns the attendance record of the student.
# c. get_average_attendance(self): Calculates and returns the average
# attendance percentage of the student based on their attendance record.

# %%
#1. What is the primary goal of Object-Oriented Programming (OOP)?

"""
Primary Goal of OOP is reusability of code and align the programming with real time scenarios.
As OOP is bases on classes and objects, it allow to have different objects for a class, inheritance relationship between classes.
OOP also allows polymorphism, abstraction and encapsulation.
"""

# %%
#2. What is an object in Python?
"""
An instance of a class is called object.
e.g. for a class Person: it can have objects like student,employee,player etc
"""

# %%
#3. What is a class in Python?

"""
Class is used to define a skeleton for its objects
"""
# Out:
# Object `Python` not found.

# %%
#4. What are attributes and methods in a class?

"""
Variables defined inside class are called its attributes. Class variables can be used to define properties of objects.
Methods defined inside class are called its method. Class methods are used to get, set attributes or to define some functionality.
"""

# %%
#5. What is the difference between class variables and instance variables in Python?
"""
Class variables are defined inside a class but outside any class methods.

Instance variables are defined inside the methods and has local scope to that method only.
"""

# %%
#6. What is the purpose of the self parameter in Python class methods?
"""
self is used to denote the calling object
"""

# %%
"""
7. For a library management system, you have to design the "Book" class with OOP
principles in mind. The “Book” class will have following attributes:
a. title: Represents the title of the book.
b. author: Represents the author(s) of the book.
c. isbn: Represents the ISBN (International Standard Book Number) of the book.
d. publication_year: Represents the year of publication of the book.
e. available_copies: Represents the number of copies available for checkout.
The class will also include the following methods:
a. check_out(self): Decrements the available copies by one if there are copies
available for checkout.
b. return_book(self): Increments the available copies by one when a book is
returned.
c. display_book_info(self): Displays the information about the book, including its
attributes and the number of available copies."""

# %%
class Book:
    def __init__(self,title,author,isbn,publication_year,available_copies):  #constructor
        self.title=title
        self.author=author
        self.isbn=isbn
        self.publication_year=publication_year
        self.available_copies=available_copies
    
    def checkout(self):
        self.available_copies=self.available_copies-1
    def return_book(self):
        self.available_copies=self.available_copies+1
    def display_book_info(self):
        print("________Book Details______")
        print(f"Title : {self.title}")
        print(f"author : {self.author}")
        print(f"isbn : {self.isbn}")
        print(f"publication_year : {self.publication_year}")
        print(f"available_copies : {self.available_copies}")
        
        

b1=Book("Mathematics","RD Sharma",2342,2015,10)
b2=Book("Harry Potter","JK Rowling",2342,2015,100)
b3=Book("Hanuman Chalisa","tulsidas",2342,2018,10)

b1.display_book_info()
b2.display_book_info()        
b3.display_book_info() 

b1.checkout()
b2.checkout()
b3.return_book()

b1.display_book_info()
b2.display_book_info()        
b3.display_book_info()
# Out:
# ________Book Details______
# Title : Mathematics
# author : RD Sharma
# isbn : 2342
# publication_year : 2015
# available_copies : 10
# ________Book Details______
# Title : Harry Potter
# author : JK Rowling
# isbn : 2342
# publication_year : 2015
# available_copies : 100
# ________Book Details______
# Title : Hanuman Chalisa
# author : tulsidas
# isbn : 2342
# publication_year : 2018
# available_copies : 10
# ________Book Details______
# Title : Mathematics
# author : RD Sharma
# isbn : 2342
# publication_year : 2015
# available_copies : 9
# ________Book Details______
# Title : Harry Potter
# author : JK Rowling
# isbn : 2342
# publication_year : 2015
# available_copies : 99
# ________Book Details______
# Title : Hanuman Chalisa
# author : tulsidas
# isbn : 2342
# publication_year : 2018
# available_copies : 11

# %%
"""
8. For a ticket booking system, you have to design the "Ticket" class with OOP
principles in mind. The “Ticket” class should have the following attributes:
a. ticket_id: Represents the unique identifier for the ticket.
b. event_name: Represents the name of the event.
c. event_date: Represents the date of the event.
d. venue: Represents the venue of the event.
e. seat_number: Represents the seat number associated with the ticket.
f. price: Represents the price of the ticket.
g. is_reserved: Represents the reservation status of the ticket.
The class also includes the following methods:
a. reserve_ticket(self): Marks the ticket as reserved if it is not already reserved.
b. cancel_reservation(self): Cancels the reservation of the ticket if it is already
reserved.
c. display_ticket_info(self): Displays the information about the ticket, including its
attributes and reservation status.
"""

# %%
class Ticket:
    def __init__(self,ticket_id,event_name,event_date,venue,seat_number,price,is_reserved):
        self.ticket_id=ticket_id
        self.event_name=event_name
        self.event_date=event_date
        self.venue=venue
        self.seat_number=seat_number
        self.price=price
        self.is_reserved=is_reserved
        
    def reserve_ticket(self):
        self.is_reserved=True
        
    def cancel_reservation(self):
        self.is_reserved=False
        
    def display_ticket_info(self):
        print("\n_____Ticket Info: ")
        print(f"Ticket id : {self.ticket_id}")
        print(f"event_name : {self.event_name}")
        print(f"event_date : {self.event_date}")
        print(f"venue : {self.venue}")
        print(f"seat_number : {self.seat_number}")
        print(f"price : {self.price}")
        print(f"is_reserved : {self.is_reserved}")
        
        
t1=Ticket(123,"New Year","31 dec","abc mall",34,678,False)
t2=Ticket(234,"X mas Party","25 dec","xyz mall",34,543,True)
t3=Ticket(654,"Diwali Party","15 Nov","mno mall",34,56,False)   

t1.display_ticket_info()
t2.display_ticket_info()
t3.display_ticket_info()

t1.reserve_ticket()
t2.cancel_reservation()
t3.reserve_ticket()

t1.display_ticket_info()
t2.display_ticket_info()
t3.display_ticket_info()
# Out:
# _____Ticket Info:
# Ticket id : 123
# event_name : New Year
# event_date : 31 dec
# venue : abc mall
# seat_number : 34
# price : 678
# is_reserved : False
#
# _____Ticket Info:
# Ticket id : 234
# event_name : X mas Party
# event_date : 25 dec
# venue : xyz mall
# seat_number : 34
# price : 543
# is_reserved : True
#
# _____Ticket Info:
# Ticket id : 654
# event_name : Diwali Party
# event_date : 15 Nov
# venue : mno mall
# seat_number : 34
# price : 56
# is_reserved : False
#
# _____Ticket Info:
# Ticket id : 123
# event_name : New Year
# event_date : 31 dec
# venue : abc mall
# seat_number : 34
# price : 678
# is_reserved : True
#
# _____Ticket Info:
# Ticket id : 234
# event_name : X mas Party
# event_date : 25 dec
# venue : xyz mall
# seat_number : 34
# price : 543
# is_reserved : False
#
# _____Ticket Info:
# Ticket id : 654
# event_name : Diwali Party
# event_date : 15 Nov
# venue : mno mall
# seat_number : 34
# price : 56
# is_reserved : True

# %%
"""
9. You are creating a shopping cart for an e-commerce website. Using OOP to model
the "ShoppingCart" functionality the class should contain following attributes and
methods:
a. items: Represents the list of items in the shopping cart.
The class also includes the following methods:

a. add_item(self, item): Adds an item to the shopping cart by appending it to the
list of items.
b. remove_item(self, item): Removes an item from the shopping cart if it exists in
the list.
c. view_cart(self): Displays the items currently present in the shopping cart.
d. clear_cart(self): Clears all items from the shopping cart by reassigning an
empty list to the items attribute.
"""

# %%
class ShoppingCart:
    def __init__(self,items):
        self.items=items
    
    def add_item(self, item):
        self.items.append(item)
        
    def remove_item(self, item):
        self.items.pop(item)
    
    def View_cart(self):
        print(self.items)
        
    def Clear_cart(self):
        self.items.clear()
        
C1=ShoppingCart(["soap","comb","noodles"])
C1.View_cart()
C1.add_item("Brush")
C1.View_cart()
C1.Clear_cart()
C1.View_cart()
C1.add_item("Nail Paint")
C1.View_cart()
# Out:
# ['soap', 'comb', 'noodles']
# ['soap', 'comb', 'noodles', 'Brush']
# []
# ['Nail Paint']

# %%
"""
10. Imagine a school management system. You have to design the "Student" class using
OOP concepts.The “Student” class has the following attributes:
a. name: Represents the name of the student.
b. age: Represents the age of the student.
c. grade: Represents the grade or class of the student.
d. student_id: Represents the unique identifier for the student.
e. attendance: Represents the attendance record of the student.
The class should also include the following methods:
a. update_attendance(self, date, status): Updates the attendance record of the
student for a given date with the provided status (e.g., present or absent).
b. get_attendance(self): Returns the attendance record of the student.
c. get_average_attendance(self): Calculates and returns the average
attendance percentage of the student based on their attendance record.
"""

# %%
class Student:
    def __init__(self,name,age,grade,student_id,date,attendance):  #added extra attribute date, as we have to store attendance date wise
        self.name=name
        self.age=age
        self.grade=grade
        self.student_id=student_id
        self.attendance={date: attendance}  # attendance stored in dictionary for each date
        
    def update_attendance(self,date,status):
        self.attendance[date]=status
        
    def get_attendance(self):
        print(f"Attendance : {self.attendance}")
    
    def get_average_attendance(self):
        present=0
        avg=0
        for value in self.attendance.values():
            
            if value=="P" or value=="p":
                present+=1
            
        avg= present/len(self.attendance)
        print(f"average attendance for a total {len(self.attendance)} days is : {avg}")
                
s1=Student("Monika",5,2,123,22042023,"P")
s1.get_attendance()
s1.update_attendance(23042023,"A")   
s1.get_attendance()
s1.get_average_attendance()
# Out:
# Attendance : {22042023: 'P'}
# Attendance : {22042023: 'P', 23042023: 'A'}
# average attendance for a total 2 days is : 0.5
